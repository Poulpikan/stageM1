# %%
import pickle
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
##############################################################################################################

# Liste des tailles de couches
layer_sizes = [4,8,16,32,64]

# Charger les résultats et les mettre dans une liste
all_data = []

for layer in layer_sizes: 
    with open(f"{layer}_layer_result.pkl", "rb") as f:
        results = pickle.load(f)
        for metrics in results:
            all_data.append({
                'layer_size': layer,
                'f1_score': metrics['f1_score'],
                'precision': metrics['precision'],
                'recall': metrics['recall']
            })


with open(f"{32}_layer_result_patience5.pkl", "rb") as f:
    results = pickle.load(f)
    for metrics in results:
        all_data.append({
            'layer_size': '32_bis',
            'f1_score': metrics['f1_score'],
            'precision': metrics['precision'],
            'recall': metrics['recall']
        })

with open(f"{64}_layer_result_patience5.pkl", "rb") as f:
    results = pickle.load(f)
    for metrics in results:
        all_data.append({
            'layer_size': '64_bis',
            'f1_score': metrics['f1_score'],
            'precision': metrics['precision'],
            'recall': metrics['recall']
        })

# Convertir en DataFrame
df = pd.DataFrame(all_data)

metrics = ['precision', 'f1_score', 'recall']
for metric in metrics:
    plt.figure(figsize=(8, 6))
    sns.boxplot(
        x='layer_size',
        y=metric,
        data=df,
        medianprops=dict(color='red', linewidth=2)
    )
    plt.title(f"Boxplot of {metric} by Layer Size")
    plt.xlabel("Layer Size")
    plt.ylabel(metric.capitalize())
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
# Liste des tailles de couches
kermel_values = [[15,15],[3,2],[100,50],[21,12],[10,5],[13,9],[18,12]]

# Charger les résultats et les mettre dans une liste
all_data = []

with open(f"{16}_layer_result.pkl", "rb") as f:
    results = pickle.load(f)
    for metrics in results:
        all_data.append({
            'layer_size':  f"s[{15}:{10}]",
            'f1_score': metrics['f1_score'],
            'precision': metrics['precision'],
            'recall': metrics['recall']
        })
        
for kermel in kermel_values: 
    with open(f"{kermel[0]}_{kermel[1]}_kermel_result.pkl", "rb") as f:
        results = pickle.load(f)
        for metrics in results:
            all_data.append({
                'layer_size': f"[{kermel[0]}:{kermel[1]}]",
                'f1_score': metrics['f1_score'],
                'precision': metrics['precision'],
                'recall': metrics['recall']
            })



# Convertir en DataFrame
df = pd.DataFrame(all_data)

# Afficher les 3 boxplots
metrics = ['precision','f1_score', 'recall']
for metric in metrics:
    plt.figure(figsize=(8, 6))
    sns.boxplot(x='layer_size', y=metric, data=df,        medianprops=dict(color='red', linewidth=2))
    plt.title(f"Boxplot of {metric} by kermel Size")
    plt.xlabel("Kermel Size")
    plt.ylabel(metric.capitalize())
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
all_data = []

with open(f"input_conv1d_globalmax_dense_result_bis.pkl", "rb") as f:
    results = pickle.load(f)
    for metrics in results:
        all_data.append({
            'layer_size':  f"1 couche",
            'f1_score': metrics['f1_score'],
            'precision': metrics['precision'],
            'recall': metrics['recall']
        })



with open(f"{16}_layer_result.pkl", "rb") as f:
    results = pickle.load(f)
    for metrics in results:
        all_data.append({
            'layer_size':  f"2 couches",
            'f1_score': metrics['f1_score'],
            'precision': metrics['precision'],
            'recall': metrics['recall']
        })







# Convertir en DataFrame
df = pd.DataFrame(all_data)

# Afficher les 3 boxplots
metrics = ['precision','f1_score', 'recall']
for metric in metrics:
    plt.figure(figsize=(8, 6))
    sns.boxplot(x='layer_size', y=metric, data=df,        medianprops=dict(color='red', linewidth=2))
    plt.title(f"Boxplot of {metric}")
    plt.xlabel("")
    plt.ylabel(metric.capitalize())
    plt.grid(True)
    plt.tight_layout()

    plt.show()

# %%
import pickle
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Liste des tailles de couches
layer_sizes = [4,8,16,32,64]

# Charger les résultats et les mettre dans une liste
all_data = []

for layer in layer_sizes: 
    with open(f"{layer}_layer_result_patience_donovani.pkl", "rb") as f:
        results = pickle.load(f)
        for metrics in results:
            all_data.append({
                'layer_size': layer,
                'f1_score': metrics['f1_score'],
                'precision': metrics['precision'],
                'recall': metrics['recall']
            })



# Convertir en DataFrame
df = pd.DataFrame(all_data)

# Afficher les 3 boxplots
metrics = ['precision','f1_score', 'recall']
for metric in metrics:
    plt.figure(figsize=(8, 6))
    sns.boxplot(x='layer_size', y=metric, data=df, medianprops=dict(color='red', linewidth=2))
    plt.title(f"Boxplot of {metric} by Layer Size")
    plt.xlabel("Layer Size")
    plt.ylabel(metric.capitalize())
    plt.grid(True)
    plt.tight_layout()
    plt.show()

#on peut couper bis et sans bis
#car il y a pas la meme epoch et que 64 n'a pas eu le teps de converger 
#64 bis on laisse le temps de converger 
#on remaque une temdenec a la baisse
#on choisis 16 car il a de meilleur performenec 
#on checkche now les kermel

# %%
import pickle
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

###################################################################################################################
#### Bis c'est le changement des données d'entrée 
#######################################################################################################################


# Liste des tailles de couches
layer_sizes = [8,16,32,64]

# Charger les résultats et les mettre dans une liste
all_data = []

for layer in layer_sizes: 
    with open(f"{layer}_layer_result_patience_all.pkl", "rb") as f:
        results = pickle.load(f)
        for metrics in results:
            all_data.append({
                'layer_size': layer,
                'f1_score': metrics['f1_score'],
                'precision': metrics['precision'],
                'recall': metrics['recall']
            })

layer_sizes = [8,16,32,64]
for layer in layer_sizes: 
    with open(f"{layer}_layer_result_patience_all_2.pkl", "rb") as f:
        results = pickle.load(f)
        for metrics in results:
            all_data.append({
                'layer_size': str(layer)+'_bis',
                'f1_score': metrics['f1_score'],
                'precision': metrics['precision'],
                'recall': metrics['recall']
            })


# Convertir en DataFrame
df = pd.DataFrame(all_data)

# Afficher les 3 boxplots
metrics = ['precision','f1_score', 'recall']
for metric in metrics:
    plt.figure(figsize=(8, 6))
    sns.boxplot(x='layer_size', y=metric, data=df, medianprops=dict(color='red', linewidth=2))
    plt.title(f"Boxplot of {metric} by Layer Size")
    plt.xlabel("Layer Size")
    plt.ylabel(metric.capitalize())
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
import pickle
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
all_data = []
with open(f"{32}_layer_result_patience_all.pkl", "rb") as f:
    results = pickle.load(f)
    for metrics in results:
        all_data.append({
            'layer_size': 16,
            'f1_score': metrics['f1_score'],
            'precision': metrics['precision'],
            'recall': metrics['recall']
        })

print("ALL layer 32")
for data in all_data:
    print(data)
# Out:
# ALL layer 16
# {'layer_size': 16, 'f1_score': 0.846441947565543, 'precision': 0.8248175182481752, 'recall': 0.8692307692307693}
# {'layer_size': 16, 'f1_score': 0.8880866425992779, 'precision': 0.8367346938775511, 'recall': 0.9461538461538461}
# {'layer_size': 16, 'f1_score': 0.9197080291970803, 'precision': 0.875, 'recall': 0.9692307692307692}
# {'layer_size': 16, 'f1_score': 0.8896797153024911, 'precision': 0.8278145695364238, 'recall': 0.9615384615384616}
# {'layer_size': 16, 'f1_score': 0.8904593639575972, 'precision': 0.8235294117647058, 'recall': 0.9692307692307692}
# {'layer_size': 16, 'f1_score': 0.8621908127208481, 'precision': 0.7973856209150327, 'recall': 0.9384615384615385}
# {'layer_size': 16, 'f1_score': 0.88, 'precision': 0.8344827586206897, 'recall': 0.9307692307692308}
# {'layer_size': 16, 'f1_score': 0.8650519031141869, 'precision': 0.7861635220125787, 'recall': 0.9615384615384616}
# ...

# %%
import pickle
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
all_data = []
with open(f"{16}_layer_result_patience_all.pkl", "rb") as f:
    results = pickle.load(f)
    for metrics in results:
        all_data.append({
            'layer_size': 16,
            'f1_score': metrics['f1_score'],
            'precision': metrics['precision'],
            'recall': metrics['recall']
        })

print("ALL layer 16")
for data in all_data:
    print(data)
# Out:
# ALL layer 16
# {'layer_size': 16, 'f1_score': 0.5846867749419954, 'precision': 0.4186046511627907, 'recall': 0.9692307692307692}
# {'layer_size': 16, 'f1_score': 0.525, 'precision': 0.36, 'recall': 0.9692307692307692}
# {'layer_size': 16, 'f1_score': 0.8710801393728222, 'precision': 0.7961783439490446, 'recall': 0.9615384615384616}
# {'layer_size': 16, 'f1_score': 0.8732394366197183, 'precision': 0.8051948051948052, 'recall': 0.9538461538461539}
# {'layer_size': 16, 'f1_score': 0.7716049382716049, 'precision': 0.6443298969072165, 'recall': 0.9615384615384616}
# {'layer_size': 16, 'f1_score': 0.3795180722891566, 'precision': 0.23595505617977527, 'recall': 0.9692307692307692}
# {'layer_size': 16, 'f1_score': 0.8491228070175438, 'precision': 0.7806451612903226, 'recall': 0.9307692307692308}
# {'layer_size': 16, 'f1_score': 0.8512110726643599, 'precision': 0.7735849056603774, 'recall': 0.9461538461538461}
# ...

# %%
import pickle
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
all_data = []
with open(f"{32}_layer_result_patience_donovani.pkl", "rb") as f:
    results = pickle.load(f)
    for metrics in results:
        all_data.append({
            'layer_size': 32,
            'f1_score': metrics['f1_score'],
            'precision': metrics['precision'],
            'recall': metrics['recall']
        })

print("Donovani layer 32")
for data in all_data:
    print(data)
# Out:
# Donovani layer 32
# {'layer_size': 32, 'f1_score': 0.7096774193548387, 'precision': 0.6470588235294118, 'recall': 0.7857142857142857}
# {'layer_size': 32, 'f1_score': 0.7368421052631579, 'precision': 0.5833333333333334, 'recall': 1.0}
# {'layer_size': 32, 'f1_score': 0.8148148148148148, 'precision': 0.8461538461538461, 'recall': 0.7857142857142857}
# {'layer_size': 32, 'f1_score': 0.7567567567567568, 'precision': 0.6086956521739131, 'recall': 1.0}
# {'layer_size': 32, 'f1_score': 0.8571428571428571, 'precision': 0.8571428571428571, 'recall': 0.8571428571428571}
# {'layer_size': 32, 'f1_score': 0.8235294117647058, 'precision': 0.7, 'recall': 1.0}
# {'layer_size': 32, 'f1_score': 0.7777777777777778, 'precision': 0.6363636363636364, 'recall': 1.0}
# {'layer_size': 32, 'f1_score': 0.8666666666666667, 'precision': 0.8125, 'recall': 0.9285714285714286}
# {'layer_size': 32, 'f1_score': 0.8, 'precision': 0.6666666666666666, 'recall': 1.0}
# ...

# %%
import pickle
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
all_data = []
with open(f"{16}_layer_result_patience_donovani.pkl", "rb") as f:
    results = pickle.load(f)
    for metrics in results:
        all_data.append({
            'layer_size': 16,
            'f1_score': metrics['f1_score'],
            'precision': metrics['precision'],
            'recall': metrics['recall']
        })

print("Donovani layer 16")
for data in all_data:
    print(data)
# Out:
# Donovani layer 16
# {'layer_size': 16, 'f1_score': 0.5, 'precision': 0.4090909090909091, 'recall': 0.6428571428571429}
# {'layer_size': 16, 'f1_score': 0.7272727272727273, 'precision': 0.631578947368421, 'recall': 0.8571428571428571}
# {'layer_size': 16, 'f1_score': 0.8, 'precision': 0.75, 'recall': 0.8571428571428571}
# {'layer_size': 16, 'f1_score': 0.6666666666666666, 'precision': 0.5, 'recall': 1.0}
# {'layer_size': 16, 'f1_score': 0.9032258064516129, 'precision': 0.8235294117647058, 'recall': 1.0}
# {'layer_size': 16, 'f1_score': 0.8387096774193549, 'precision': 0.7647058823529411, 'recall': 0.9285714285714286}
# {'layer_size': 16, 'f1_score': 0.5306122448979592, 'precision': 0.37142857142857144, 'recall': 0.9285714285714286}
# {'layer_size': 16, 'f1_score': 0.6875, 'precision': 0.6111111111111112, 'recall': 0.7857142857142857}
# {'layer_size': 16, 'f1_score': 0.6470588235294118, 'precision': 0.55, 'recall': 0.7857142857142857}
# ...

# %%
import pickle
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
all_data = []
with open(f"{16}_layer_result.pkl", "rb") as f:
    results = pickle.load(f)
    for metrics in results:
        all_data.append({
            'layer_size': 32,
            'f1_score': metrics['f1_score'],
            'precision': metrics['precision'],
            'recall': metrics['recall']
        })

print("Major layer 16")
for data in all_data:
    print(data)
# Out:
# Major layer 16
# {'layer_size': 32, 'f1_score': 0.8125, 'precision': 0.7222222222222222, 'recall': 0.9285714285714286}
# {'layer_size': 32, 'f1_score': 0.6285714285714286, 'precision': 0.5238095238095238, 'recall': 0.7857142857142857}
# {'layer_size': 32, 'f1_score': 0.7428571428571429, 'precision': 0.6190476190476191, 'recall': 0.9285714285714286}
# {'layer_size': 32, 'f1_score': 0.7567567567567568, 'precision': 0.6086956521739131, 'recall': 1.0}
# {'layer_size': 32, 'f1_score': 0.6875, 'precision': 0.6111111111111112, 'recall': 0.7857142857142857}
# {'layer_size': 32, 'f1_score': 0.6060606060606061, 'precision': 0.5263157894736842, 'recall': 0.7142857142857143}
# {'layer_size': 32, 'f1_score': 0.8571428571428571, 'precision': 0.8571428571428571, 'recall': 0.8571428571428571}
# {'layer_size': 32, 'f1_score': 0.7777777777777778, 'precision': 0.6363636363636364, 'recall': 1.0}
# ...

# %%
import pickle
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
all_data = []
with open(f"{32}_layer_result.pkl", "rb") as f:
    results = pickle.load(f)
    for metrics in results:
        all_data.append({
            'layer_size': 32,
            'f1_score': metrics['f1_score'],
            'precision': metrics['precision'],
            'recall': metrics['recall']
        })

print("Donovani layer 32")
for data in all_data:
    print(data)
# Out:
# Donovani layer 32
# {'layer_size': 32, 'f1_score': 0.7647058823529411, 'precision': 0.65, 'recall': 0.9285714285714286}
# {'layer_size': 32, 'f1_score': 0.5365853658536586, 'precision': 0.4074074074074074, 'recall': 0.7857142857142857}
# {'layer_size': 32, 'f1_score': 0.7567567567567568, 'precision': 0.6086956521739131, 'recall': 1.0}
# {'layer_size': 32, 'f1_score': 0.7272727272727273, 'precision': 0.631578947368421, 'recall': 0.8571428571428571}
# {'layer_size': 32, 'f1_score': 0.7027027027027027, 'precision': 0.5652173913043478, 'recall': 0.9285714285714286}
# {'layer_size': 32, 'f1_score': 0.7586206896551724, 'precision': 0.7333333333333333, 'recall': 0.7857142857142857}
# {'layer_size': 32, 'f1_score': 0.7142857142857143, 'precision': 0.7142857142857143, 'recall': 0.7142857142857143}
# {'layer_size': 32, 'f1_score': 0.6666666666666666, 'precision': 0.5, 'recall': 1.0}
# {'layer_size': 32, 'f1_score': 0.39436619718309857, 'precision': 0.24561403508771928, 'recall': 1.0}
# ...

# %%
import pickle
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
all_data = []
with open(f"{32}_layer_result_patience_all_2.pkl", "rb") as f:
    results = pickle.load(f)
    for metrics in results:
        all_data.append({
            'layer_size': 32,
            'f1_score': metrics['f1_score'],
            'precision': metrics['precision'],
            'recall': metrics['recall']
        })

print("All layer 32")
for data in all_data:
    print(data)

#32 5
# Out:
# All layer 32
# {'layer_size': 32, 'f1_score': 0.9230769230769231, 'precision': 0.9017341040462428, 'recall': 0.9454545454545454}
# {'layer_size': 32, 'f1_score': 0.9147727272727273, 'precision': 0.8609625668449198, 'recall': 0.9757575757575757}
# {'layer_size': 32, 'f1_score': 0.9364161849710982, 'precision': 0.8950276243093923, 'recall': 0.9818181818181818}
# {'layer_size': 32, 'f1_score': 0.9195402298850575, 'precision': 0.8743169398907104, 'recall': 0.9696969696969697}
# {'layer_size': 32, 'f1_score': 0.9394812680115274, 'precision': 0.8956043956043956, 'recall': 0.9878787878787879}
# {'layer_size': 32, 'f1_score': 0.9209039548022598, 'precision': 0.8624338624338624, 'recall': 0.9878787878787879}
# {'layer_size': 32, 'f1_score': 0.8932584269662921, 'precision': 0.8324607329842932, 'recall': 0.9636363636363636}
# {'layer_size': 32, 'f1_score': 0.9217391304347826, 'precision': 0.8833333333333333, 'recall': 0.9636363636363636}
# ...

# %%
import pickle
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
all_data = []
with open(f"{16}_layer_result_patience_all_2.pkl", "rb") as f:
    results = pickle.load(f)
    for metrics in results:
        all_data.append({
            'layer_size': 32,
            'f1_score': metrics['f1_score'],
            'precision': metrics['precision'],
            'recall': metrics['recall']
        })

print("All layer 32")
for data in all_data:
    print(data)
# Out:
# All layer 32
# {'layer_size': 32, 'f1_score': 0.9221902017291066, 'precision': 0.8791208791208791, 'recall': 0.9696969696969697}
# {'layer_size': 32, 'f1_score': 0.8626373626373627, 'precision': 0.7889447236180904, 'recall': 0.9515151515151515}
# {'layer_size': 32, 'f1_score': 0.8293963254593176, 'precision': 0.7314814814814815, 'recall': 0.9575757575757575}
# {'layer_size': 32, 'f1_score': 0.8705234159779615, 'precision': 0.797979797979798, 'recall': 0.9575757575757575}
# {'layer_size': 32, 'f1_score': 0.9317507418397626, 'precision': 0.9127906976744186, 'recall': 0.9515151515151515}
# {'layer_size': 32, 'f1_score': 0.9221902017291066, 'precision': 0.8791208791208791, 'recall': 0.9696969696969697}
# {'layer_size': 32, 'f1_score': 0.8760330578512396, 'precision': 0.803030303030303, 'recall': 0.9636363636363636}
# {'layer_size': 32, 'f1_score': 0.9285714285714286, 'precision': 0.9122807017543859, 'recall': 0.9454545454545454}
# ...

# %%
import pickle
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
###################################################################################################################
#### que le bis
#######################################################################################################################
# Liste des tailles de couches
layer_sizes = [8,16,32,64]

# Charger les résultats et les mettre dans une liste
all_data = []

layer_sizes = [8,16,32,64]
for layer in layer_sizes: 
    with open(f"{layer}_layer_result_patience_all_2.pkl", "rb") as f:
        results = pickle.load(f)
        for metrics in results:
            all_data.append({
                'layer_size': str(layer),
                'f1_score': metrics['f1_score'],
                'precision': metrics['precision'],
                'recall': metrics['recall']
            })


# Convertir en DataFrame
df = pd.DataFrame(all_data)

# Afficher les 3 boxplots
metrics = ['precision','f1_score', 'recall']
for metric in metrics:
    plt.figure(figsize=(8, 6))
    sns.boxplot(x='layer_size', y=metric, data=df, medianprops=dict(color='red', linewidth=2))
    plt.title(f"Boxplot of {metric} by Filter Size")
    plt.xlabel("Filter Size")
    plt.ylabel(metric.capitalize())
    plt.grid(True)
    plt.tight_layout()

    plt.show()
